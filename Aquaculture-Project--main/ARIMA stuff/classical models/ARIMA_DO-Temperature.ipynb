# %% [markdown]
# **Dissolved Oxygen**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
from sklearn.metrics import mean_squared_error
from math import sqrt


data = pd.read_csv('../Pretreated data.csv')
data.head()
# Load the dataset and prepare the data
do = data[['date', 'DO(mg/l)']]
do = do.set_index('date')

# Step 1: ADF test on the original data
adf_result = adfuller(do['DO(mg/l)'])
print(f'ADF Statistic (original): {adf_result[0]}')
print(f'p-value (original): {adf_result[1]}')

# Step 2: Apply differencing
do_diff = do['DO(mg/l)'].diff().dropna()

# Step 3: ADF test on the differenced data
adf_result_diff = adfuller(do_diff)
print(f'ADF Statistic (differenced): {adf_result_diff[0]}')
print(f'p-value (differenced): {adf_result_diff[1]}')
# Out:
# ADF Statistic (original): -7.971149647083841
# p-value (original): 2.7790848183701384e-12
# ADF Statistic (differenced): -20.314002445102254
# p-value (differenced): 0.0

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(do_diff).set_xlim([0, 10])
# Out:
# (0.0, 10.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error
from math import sqrt


# Best Parameters: {'d': 0, 'p': 4, 'q': 18, 'trend': 'ct'}
# Best Loss: 0.00041905043113688603
# Load the dataset and prepare the data
data = pd.read_csv('../Pretreated data.csv')
do = data[['date', 'DO(mg/l)']]
do = do.set_index('date')

# Splitting the data: 98.5% train, 1.5% test
size = int(len(do) * 0.985)
train, test = do[0:size], do[size:len(do)]
history = [x for x in train['DO(mg/l)']]  # Extract the DO column data for history
predictions = list()

# Fit ARIMA model once on the training data
model = ARIMA(history, order=(3, 1, 0))  # Adjust order as needed
model_fit = model.fit()

# Walk-forward validation with rolling predictions
for t in range(len(test)):
    # Forecast using the model (without re-fitting)
    output = model_fit.forecast(steps=1)
    yhat = output[0]
    predictions.append(yhat)

    # Update history with the actual observation
    obs = test['DO(mg/l)'].iloc[t]
    history.append(obs)  # Update the history

    # Re-initialize the model with updated history to update forecast
    model_fit = model_fit.append([obs], refit=False)

    print(f'Iter={t}, predicted={yhat:.6f}, expected={obs:.6f}')

# Evaluation metrics
rmse = sqrt(mean_squared_error(test, predictions))
mae = mean_absolute_error(test, predictions)
mape = np.mean(np.abs((test['DO(mg/l)'] - predictions) / test['DO(mg/l)'])) * 100

# Print metrics
print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Absolute Percentage Error (MAPE): {mape}%')

# Reset index for proper plotting
test = test.reset_index(drop=True)

# Plot the test data and predictions using numeric index
plt.figure(figsize=(12, 6))
plt.plot(test.index, test, label='Test Data', color='blue')
plt.plot(test.index, predictions, label='Predictions', color='red', linestyle='--')
plt.title('DO Levels: Actual vs Predicted (Walk-Forward Validation)')
plt.xlabel('Index')
plt.ylabel('DO (mg/l)')
plt.legend()
plt.show()
# Out:
# Iter=0, predicted=2.770773, expected=2.765549
# Iter=1, predicted=2.734105, expected=2.726125
# Iter=2, predicted=2.688021, expected=2.680662
# Iter=3, predicted=2.637034, expected=2.627731
# Iter=4, predicted=2.576739, expected=2.572516
# Iter=5, predicted=2.521612, expected=2.525908
# Iter=6, predicted=2.487084, expected=2.505704
# Iter=7, predicted=2.497757, expected=2.498652
# Iter=8, predicted=2.496603, expected=2.501476
# Iter=9, predicted=2.507578, expected=2.502888
# Iter=10, predicted=2.503226, expected=2.503594
# Iter=11, predicted=2.504002, expected=2.503947
# Iter=12, predicted=2.504151, expected=2.504123
# Iter=13, predicted=2.504225, expected=2.504212
# Iter=14, predicted=2.504263, expected=2.504256
# Iter=15, predicted=2.504281, expected=2.504278
# Iter=16, predicted=2.504291, expected=2.504289
# Iter=17, predicted=2.504295, expected=2.504294
# Iter=18, predicted=2.504298, expected=2.509447
# Iter=19, predicted=2.516236, expected=2.515624
# Iter=20, predicted=2.521469, expected=2.522862
# Iter=21, predicted=2.529844, expected=2.531231
# Iter=22, predicted=2.539269, expected=2.541565
# Iter=23, predicted=2.551730, expected=2.555283
# Iter=24, predicted=2.569072, expected=2.548424
# Iter=25, predicted=2.533666, expected=2.544995
# Iter=26, predicted=2.544046, expected=2.543280
# Iter=27, predicted=2.542290, expected=2.542423
# Iter=28, predicted=2.541928, expected=2.541994
# Iter=29, predicted=2.541747, expected=2.541780
# Iter=30, predicted=2.541656, expected=2.541673
# Iter=31, predicted=2.541611, expected=2.541619
# Iter=32, predicted=2.541588, expected=2.541592
# Iter=33, predicted=2.541577, expected=2.540196
# Iter=34, predicted=2.538366, expected=2.519998
# Iter=35, predicted=2.494001, expected=2.485599
# Iter=36, predicted=2.449209, expected=2.442650
# Iter=37, predicted=2.400608, expected=2.396325
# Iter=38, predicted=2.353109, expected=2.348912
# Iter=39, predicted=2.305445, expected=2.303156
# Iter=40, predicted=2.262229, expected=2.258378
# Iter=41, predicted=2.217961, expected=2.231389
# Iter=42, predicted=2.214042, expected=2.244884
# Iter=43, predicted=2.273001, expected=2.251631
# Iter=44, predicted=2.253498, expected=2.255004
# Iter=45, predicted=2.256953, expected=2.256691
# Iter=46, predicted=2.257666, expected=2.257535
# Iter=47, predicted=2.258022, expected=2.257956
# Iter=48, predicted=2.258200, expected=2.258167
# Iter=49, predicted=2.258289, expected=2.258062
# Iter=50, predicted=2.257845, expected=2.258009
# Iter=51, predicted=2.257995, expected=2.257983
# Iter=52, predicted=2.257968, expected=2.257970
# Iter=53, predicted=2.257962, expected=2.257963
# Iter=54, predicted=2.257959, expected=2.257960
# Iter=55, predicted=2.257958, expected=2.257958
# Iter=56, predicted=2.257957, expected=2.257957
# Iter=57, predicted=2.257957, expected=2.257957
# Iter=58, predicted=2.257957, expected=2.207228
# Iter=59, predicted=2.140377, expected=2.083514
# Iter=60, predicted=1.943071, expected=2.037707
# Iter=61, predicted=2.030525, expected=2.054604
# Iter=62, predicted=2.092616, expected=2.063052
# Iter=63, predicted=2.064938, expected=2.067276
# Iter=64, predicted=2.069716, expected=2.069388
# Iter=65, predicted=2.070608, expected=2.070444
# Iter=66, predicted=2.071054, expected=2.070972
# Iter=67, predicted=2.071277, expected=2.071236
# Iter=68, predicted=2.071388, expected=2.071368
# Iter=69, predicted=2.071444, expected=2.071434
# Iter=70, predicted=2.071472, expected=2.071467
# Iter=71, predicted=2.071486, expected=2.082784
# Iter=72, predicted=2.097684, expected=2.095442
# Iter=73, predicted=2.107085, expected=2.120671
# Iter=74, predicted=2.148707, expected=2.141785
# Iter=75, predicted=2.158852, expected=2.152343
# Iter=76, predicted=2.157802, expected=2.158471
# Iter=77, predicted=2.162641, expected=2.166136
# Iter=78, predicted=2.173904, expected=2.183068
# Iter=79, predicted=2.202199, expected=2.220434
# Iter=80, predicted=2.262424, expected=2.268367
# Iter=81, predicted=2.315531, expected=2.313283
# Iter=82, predicted=2.352536, expected=2.357742
# Iter=83, predicted=2.398131, expected=2.366721
# Iter=84, predicted=2.360445, expected=2.362231
# Iter=85, predicted=2.353988, expected=2.359987
# Iter=86, predicted=2.359365, expected=2.358864
# Iter=87, predicted=2.358216, expected=2.358303
# Iter=88, predicted=2.357979, expected=2.358022
# Iter=89, predicted=2.357860, expected=2.357882
# Iter=90, predicted=2.357801, expected=2.357812
# Iter=91, predicted=2.357771, expected=2.357777
# Iter=92, predicted=2.357757, expected=2.357759
# Iter=93, predicted=2.357749, expected=2.344880
# Iter=94, predicted=2.327913, expected=2.319290
# Iter=95, predicted=2.291302, expected=2.293295
# Iter=96, predicted=2.269949, expected=2.268647
# Iter=97, predicted=2.246780, expected=2.243674
# Iter=98, predicted=2.220761, expected=2.222237
# Iter=99, predicted=2.204181, expected=2.221118
# Iter=100, predicted=2.228251, expected=2.221678
# Iter=101, predicted=2.222106, expected=2.221957
# Iter=102, predicted=2.222035, expected=2.222097
# Iter=103, predicted=2.222178, expected=2.222167
# Iter=104, predicted=2.222207, expected=2.222202
# Iter=105, predicted=2.222222, expected=2.222219
# Iter=106, predicted=2.222229, expected=2.222228
# Iter=107, predicted=2.222233, expected=2.222232
# Iter=108, predicted=2.222235, expected=2.222235
# Iter=109, predicted=2.222236, expected=2.233817
# Iter=110, predicted=2.249080, expected=2.254109
# Iter=111, predicted=2.275691, expected=2.280404
# Iter=112, predicted=2.306457, expected=2.311302
# Iter=113, predicted=2.341073, expected=2.346751
# Iter=114, predicted=2.380696, expected=2.385726
# Iter=115, predicted=2.422463, expected=2.427363
# Iter=116, predicted=2.466211, expected=2.449281
# Iter=117, predicted=2.461090, expected=2.447191
# Iter=118, predicted=2.436241, expected=2.446145
# Iter=119, predicted=2.446523, expected=2.445623
# Iter=120, predicted=2.445321, expected=2.445361
# Iter=121, predicted=2.445210, expected=2.445231
# Iter=122, predicted=2.445155, expected=2.445165
# Iter=123, predicted=2.445128, expected=2.445133
# Iter=124, predicted=2.445114, expected=2.445116
# Iter=125, predicted=2.445107, expected=2.445108
# Iter=126, predicted=2.445103, expected=2.445104
# Iter=127, predicted=2.445102, expected=2.437302
# Iter=128, predicted=2.427022, expected=2.426351
# Iter=129, predicted=2.415394, expected=2.411126
# Iter=130, predicted=2.395644, expected=2.396113
# Iter=131, predicted=2.382697, expected=2.384106
# Iter=132, predicted=2.374397, expected=2.372353
# Iter=133, predicted=2.361647, expected=2.357927
# Iter=134, predicted=2.343697, expected=2.338863
# Iter=135, predicted=2.319724, expected=2.312082
# Iter=136, predicted=2.284735, expected=2.280341
# Iter=137, predicted=2.249721, expected=2.265020
# Iter=138, predicted=2.257958, expected=2.272681
# Iter=139, predicted=2.288404, expected=2.276511
# Iter=140, predicted=2.277571, expected=2.278426
# Iter=141, predicted=2.279532, expected=2.279383
# Iter=142, predicted=2.279936, expected=2.279862
# Iter=143, predicted=2.280139, expected=2.280101
# Iter=144, predicted=2.280240, expected=2.280221
# Iter=145, predicted=2.280290, expected=2.280281
# Iter=146, predicted=2.280316, expected=2.280311
# Iter=147, predicted=2.280328, expected=2.309605
# Iter=148, predicted=2.348199, expected=2.368753
# Iter=149, predicted=2.433654, expected=2.435226
# Iter=150, predicted=2.497590, expected=2.498263
# Iter=151, predicted=2.553958, expected=2.545832
# Iter=152, predicted=2.582947, expected=2.569616
# Iter=153, predicted=2.582147, expected=2.581508
# Iter=154, predicted=2.588377, expected=2.587454
# Iter=155, predicted=2.590889, expected=2.590427
# Iter=156, predicted=2.592144, expected=2.591913
# Iter=157, predicted=2.592772, expected=2.593400
# Iter=158, predicted=2.594809, expected=2.595200
# Iter=159, predicted=2.596966, expected=2.609150
# Iter=160, predicted=2.626788, expected=2.631025
# Iter=161, predicted=2.653708, expected=2.637662
# Iter=162, predicted=2.637193, expected=2.634344
# Iter=163, predicted=2.627837, expected=2.632684
# Iter=164, predicted=2.632225, expected=2.631855
# Iter=165, predicted=2.631375, expected=2.631440
# Iter=166, predicted=2.631200, expected=2.631232
# Iter=167, predicted=2.631113, expected=2.631129
# Iter=168, predicted=2.631069, expected=2.631077
# Iter=169, predicted=2.631047, expected=2.631051
# Iter=170, predicted=2.631036, expected=2.631038
# Iter=171, predicted=2.631030, expected=2.604869
# Iter=172, predicted=2.570388, expected=2.558084
# Iter=173, predicted=2.508084, expected=2.503442
# Iter=174, predicted=2.451283, expected=2.448371
# Iter=175, predicted=2.398370, expected=2.400236
# Iter=176, predicted=2.359270, expected=2.357318
# Iter=177, predicted=2.320124, expected=2.315509
# Iter=178, predicted=2.277714, expected=2.278154
# Iter=179, predicted=2.245932, expected=2.247427
# Iter=180, predicted=2.221996, expected=2.219264
# Iter=181, predicted=2.194427, expected=2.189382
# Iter=182, predicted=2.161389, expected=2.155141
# Iter=183, predicted=2.122265, expected=2.112570
# Iter=184, predicted=2.070594, expected=2.129385
# Iter=185, predicted=2.169213, expected=2.137793
# Iter=186, predicted=2.139783, expected=2.141996
# Iter=187, predicted=2.144425, expected=2.144098
# Iter=188, predicted=2.145312, expected=2.145149
# Iter=189, predicted=2.145756, expected=2.145675
# Iter=190, predicted=2.145978, expected=2.145937
# Iter=191, predicted=2.146089, expected=2.146069
# Iter=192, predicted=2.146145, expected=2.146134
# Iter=193, predicted=2.146172, expected=2.146167
# Iter=194, predicted=2.146186, expected=2.234134
# Iter=195, predicted=2.350046, expected=2.390567
# Iter=196, predicted=2.557547, expected=2.578233
# Iter=197, predicted=2.759192, expected=2.673817
# Iter=198, predicted=2.722092, expected=2.708658
# Iter=199, predicted=2.719067, expected=2.712929
# Iter=200, predicted=2.706637, expected=2.710794
# Iter=201, predicted=2.707388, expected=2.709726
# Iter=202, predicted=2.709431, expected=2.709192
# Iter=203, predicted=2.708884, expected=2.708925
# Iter=204, predicted=2.708771, expected=2.708792
# Iter=205, predicted=2.708715, expected=2.708725
# Iter=206, predicted=2.708687, expected=2.708692
# Iter=207, predicted=2.708672, expected=2.708675
# Iter=208, predicted=2.708665, expected=2.708667
# Iter=209, predicted=2.708662, expected=2.683133
# Iter=210, predicted=2.649488, expected=2.644617
# Iter=211, predicted=2.605229, expected=2.604058
# Iter=212, predicted=2.566801, expected=2.569479
# Iter=213, predicted=2.540522, expected=2.556840
# Iter=214, predicted=2.554056, expected=2.550520
# Iter=215, predicted=2.546519, expected=2.547360
# Iter=216, predicted=2.545535, expected=2.545780
# Iter=217, predicted=2.544867, expected=2.544990
# Iter=218, predicted=2.544534, expected=2.544595
# Iter=219, predicted=2.544367, expected=2.544397
# Iter=220, predicted=2.544283, expected=2.544299
# Iter=221, predicted=2.544242, expected=2.544249
# Iter=222, predicted=2.544221, expected=2.544225
# Iter=223, predicted=2.544210, expected=2.536212
# Iter=224, predicted=2.525663, expected=2.516906
# Iter=225, predicted=2.495031, expected=2.490603
# Iter=226, predicted=2.464236, expected=2.449452
# Iter=227, predicted=2.406208, expected=2.387276
# Iter=228, predicted=2.322675, expected=2.314838
# Iter=229, predicted=2.245518, expected=2.244669
# Iter=230, predicted=2.182118, expected=2.182484
# Iter=231, predicted=2.129059, expected=2.168192
# Iter=232, predicted=2.174410, expected=2.175338
# Iter=233, predicted=2.188781, expected=2.178911
# Iter=234, predicted=2.179900, expected=2.180698
# Iter=235, predicted=2.181730, expected=2.181591
# Iter=236, predicted=2.182107, expected=2.182038
# Iter=237, predicted=2.182296, expected=2.182261
# Iter=238, predicted=2.182390, expected=2.182373
# Iter=239, predicted=2.182437, expected=2.182429
# Iter=240, predicted=2.182461, expected=2.182457
# Iter=241, predicted=2.182473, expected=2.215228
# Iter=242, predicted=2.258405, expected=2.293064
# Iter=243, predicted=2.381045, expected=2.371082
# Iter=244, predicted=2.440467, expected=2.358191
# Iter=245, predicted=2.309388, expected=2.351746
# Iter=246, predicted=2.351926, expected=2.348523
# Iter=247, predicted=2.346661, expected=2.346911
# Iter=248, predicted=2.345981, expected=2.346106
# Iter=249, predicted=2.345640, expected=2.346509
# Iter=250, predicted=2.347338, expected=2.346710
# Iter=251, predicted=2.346766, expected=2.346811
# Iter=252, predicted=2.346869, expected=2.346861
# Iter=253, predicted=2.346890, expected=2.346886
# Iter=254, predicted=2.346901, expected=2.346899
# Iter=255, predicted=2.346906, expected=2.346905
# Iter=256, predicted=2.346909, expected=2.346908
# Iter=257, predicted=2.346910, expected=2.346910
# Iter=258, predicted=2.346911, expected=2.348455
# Iter=259, predicted=2.350490, expected=2.347682
# Iter=260, predicted=2.345976, expected=2.347296
# Iter=261, predicted=2.347189, expected=2.347103
# Iter=262, predicted=2.346991, expected=2.347006
# Iter=263, predicted=2.346951, expected=2.346958
# Iter=264, predicted=2.346930, expected=2.346934
# Iter=265, predicted=2.346920, expected=2.346946
# Iter=266, predicted=2.346971, expected=2.346952
# Iter=267, predicted=2.346954, expected=2.346955
# Iter=268, predicted=2.346957, expected=2.346957
# Iter=269, predicted=2.346957, expected=2.346957
# Iter=270, predicted=2.346958, expected=2.346958
# Iter=271, predicted=2.346958, expected=2.346958
# Iter=272, predicted=2.346958, expected=2.346958
# Iter=273, predicted=2.346958, expected=2.346958
# Iter=274, predicted=2.346958, expected=2.380129
# Iter=275, predicted=2.423842, expected=2.468665
# Iter=276, predicted=2.570567, expected=2.489332
# Iter=277, predicted=2.478390, expected=2.478998
# Iter=278, predicted=2.459506, expected=2.473831
# Iter=279, predicted=2.472401, expected=2.471248
# Iter=280, predicted=2.469756, expected=2.469956
# Iter=281, predicted=2.469210, expected=2.469310
# Iter=282, predicted=2.468937, expected=2.468987
# Iter=283, predicted=2.468801, expected=2.468826
# Iter=284, predicted=2.468733, expected=2.468745
# Iter=285, predicted=2.468699, expected=2.468705
# Iter=286, predicted=2.468682, expected=2.458002
# Iter=287, predicted=2.443913, expected=2.462601
# Iter=288, predicted=2.473426, expected=2.464901
# Iter=289, predicted=2.465480, expected=2.466050
# Iter=290, predicted=2.466714, expected=2.466625
# Iter=291, predicted=2.466957, expected=2.466913
# Iter=292, predicted=2.467079, expected=2.467056
# Iter=293, predicted=2.467139, expected=2.467128
# Iter=294, predicted=2.467170, expected=2.467164
# Iter=295, predicted=2.467185, expected=2.467182
# Iter=296, predicted=2.467192, expected=2.467191
# Iter=297, predicted=2.467196, expected=2.505796
# Iter=298, predicted=2.556666, expected=2.576948
# Iter=299, predicted=2.653523, expected=2.680324
# Root Mean Squared Error (RMSE): 0.015918584205575403
# Mean Absolute Error (MAE): 0.006896752769851161
# Mean Absolute Percentage Error (MAPE): 0.29416443059631964%

# %% [markdown]
# **TEMPERATURE**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Example: Assuming 'data' is your DataFrame containing the time series data (DO levels)
# data['DO(mg/l)'] should be the column you are analyzing
# First, perform differencing
differenced_Tdata = (data['Temp(degC)'].diff().dropna())

# # Plot ACF and PACF for the differenced data
# plt.figure(figsize=(12, 6))

# # ACF plot
# plt.subplot(121)
# plot_acf(differenced_Tdata, lags=50, ax=plt.gca())
# plt.title('ACF of Differenced Data')

# # PACF plot
# plt.subplot(122)
# plot_pacf(differenced_Tdata, lags=50, ax=plt.gca())
# plt.title('PACF of Differenced Data')

# plt.tight_layout()
# plt.show()

# (26,1,0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from math import sqrt

# Load the dataset and prepare the data
tem = data[['date', 'Temp(degC)']]
tem = tem.set_index('date')

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(differenced_Tdata).set_xlim([0, 20])
# Out:
# (0.0, 20.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error
from math import sqrt


# Splitting the data: 98.5% train, 1.5% test
size = int(len(tem) * 0.985)
train, test = tem[0:size], tem[size:len(tem)]
history = [x for x in train['Temp(degC)']]  # Extract the temperature column data for history
predictions = list()

# Fit ARIMA model once on the training data
model = ARIMA(history, order=(3, 1, 0))  # Adjust order as needed
model_fit = model.fit()

# Walk-forward validation with rolling predictions
for t in range(len(test)):
    # Forecast using the model (without re-fitting)
    output = model_fit.forecast(steps=1)
    yhat = output[0]
    predictions.append(yhat)

    # Update history with the actual observation
    obs = test['Temp(degC)'].iloc[t]
    history.append(obs)  # Update the history

    # Re-initialize the model with updated history to update forecast
    model_fit = model_fit.append([obs], refit=False)

    print(f'Iter={t}, predicted={yhat:.6f}, expected={obs:.6f}')

# Evaluation metrics
rmse = sqrt(mean_squared_error(test, predictions))
mae = mean_absolute_error(test, predictions)
mape = np.mean(np.abs((test['Temp(degC)'] - predictions) / test['Temp(degC)'])) * 100

# Print metrics
print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Absolute Percentage Error (MAPE): {mape}%')

# Reset index for proper plotting
test = test.reset_index(drop=True)

# Plot the test data and predictions using numeric index
plt.figure(figsize=(12, 6))
plt.plot(test.index, test, label='Test Data', color='blue')
plt.plot(test.index, predictions, label='Predictions', color='red', linestyle='--')
plt.title('Temp(degC): Actual vs Predicted (Walk-Forward Validation)')
plt.xlabel('Index')
plt.ylabel('Temp(degC)')
plt.legend()
plt.show()
# Out:
# Iter=0, predicted=27.507450, expected=27.507421
# Iter=1, predicted=27.507474, expected=27.507460
# Iter=2, predicted=27.507486, expected=27.507479
# Iter=3, predicted=27.507493, expected=27.507489
# Iter=4, predicted=27.507496, expected=27.507494
# Iter=5, predicted=27.507497, expected=27.505000
# Iter=6, predicted=27.502560, expected=27.511000
# Iter=7, predicted=27.516995, expected=27.513000
# Iter=8, predicted=27.514772, expected=27.513000
# Iter=9, predicted=27.512613, expected=27.516000
# Iter=10, predicted=27.518839, expected=27.518000
# Iter=11, predicted=27.519805, expected=27.517000
# Iter=12, predicted=27.515778, expected=27.517000
# Iter=13, predicted=27.516955, expected=27.518000
# Iter=14, predicted=27.519026, expected=27.520000
# Iter=15, predicted=27.521906, expected=27.525000
# Iter=16, predicted=27.529742, expected=27.531000
# Iter=17, predicted=27.536521, expected=27.535000
# Iter=18, predicted=27.538371, expected=27.539000
# Iter=19, predicted=27.542425, expected=27.543000
# Iter=20, predicted=27.546520, expected=27.547000
# Iter=21, predicted=27.550520, expected=27.550000
# Iter=22, predicted=27.552542, expected=27.551000
# Iter=23, predicted=27.551636, expected=27.550000
# Iter=24, predicted=27.548828, expected=27.548000
# Iter=25, predicted=27.546047, expected=27.545000
# Iter=26, predicted=27.542214, expected=27.539000
# Iter=27, predicted=27.533378, expected=27.532000
# Iter=28, predicted=27.525599, expected=27.525000
# Iter=29, predicted=27.518792, expected=27.518000
# Iter=30, predicted=27.511840, expected=27.512000
# Iter=31, predicted=27.506818, expected=27.507000
# Iter=32, predicted=27.502746, expected=27.503000
# Iter=33, predicted=27.499626, expected=27.499000
# Iter=34, predicted=27.495527, expected=27.495000
# Iter=35, predicted=27.491480, expected=27.492000
# Iter=36, predicted=27.489458, expected=27.490000
# Iter=37, predicted=27.488386, expected=27.488000
# Iter=38, predicted=27.486288, expected=27.487000
# Iter=39, predicted=27.486218, expected=27.486000
# Iter=40, predicted=27.485168, expected=27.487000
# Iter=41, predicted=27.488076, expected=27.489000
# Iter=42, predicted=27.490953, expected=27.493000
# Iter=43, predicted=27.496764, expected=27.499000
# Iter=44, predicted=27.504572, expected=27.504000
# Iter=45, predicted=27.508397, expected=27.508000
# Iter=46, predicted=27.511374, expected=27.510000
# Iter=47, predicted=27.511516, expected=27.510000
# Iter=48, predicted=27.509708, expected=27.509000
# Iter=49, predicted=27.507927, expected=27.506000
# Iter=50, predicted=27.503116, expected=27.501000
# Iter=51, predicted=27.496308, expected=27.493000
# Iter=52, predicted=27.485570, expected=27.485000
# Iter=53, predicted=27.477817, expected=27.481000
# Iter=54, predicted=27.477872, expected=27.474500
# Iter=55, predicted=27.468725, expected=27.467750
# Iter=56, predicted=27.461666, expected=27.460375
# Iter=57, predicted=27.453812, expected=27.451687
# Iter=58, predicted=27.443884, expected=27.441844
# Iter=59, predicted=27.433005, expected=27.443422
# Iter=60, predicted=27.445876, expected=27.444211
# Iter=61, predicted=27.445372, expected=27.444605
# Iter=62, predicted=27.444876, expected=27.444803
# Iter=63, predicted=27.444938, expected=27.444901
# Iter=64, predicted=27.444969, expected=27.444951
# Iter=65, predicted=27.444985, expected=27.444975
# Iter=66, predicted=27.444992, expected=27.444988
# Iter=67, predicted=27.444996, expected=27.444994
# Iter=68, predicted=27.444998, expected=27.444997
# Iter=69, predicted=27.444999, expected=27.451998
# Iter=70, predicted=27.458847, expected=27.461999
# Iter=71, predicted=27.471428, expected=27.471500
# Iter=72, predicted=27.479954, expected=27.481250
# Iter=73, predicted=27.489831, expected=27.491625
# Iter=74, predicted=27.500829, expected=27.501812
# Iter=75, predicted=27.510789, expected=27.501406
# Iter=76, predicted=27.500000, expected=27.501203
# Iter=77, predicted=27.500540, expected=27.501102
# Iter=78, predicted=27.501032, expected=27.501051
# Iter=79, predicted=27.501016, expected=27.501025
# Iter=80, predicted=27.501008, expected=27.501013
# Iter=81, predicted=27.501004, expected=27.501006
# Iter=82, predicted=27.501002, expected=27.501003
# Iter=83, predicted=27.501001, expected=27.501002
# Iter=84, predicted=27.501001, expected=27.501001
# Iter=85, predicted=27.501000, expected=27.501001
# Iter=86, predicted=27.501002, expected=27.501001
# Iter=87, predicted=27.501002, expected=27.501001
# Iter=88, predicted=27.501002, expected=27.501002
# Iter=89, predicted=27.501002, expected=27.501002
# Iter=90, predicted=27.501002, expected=27.501002
# Iter=91, predicted=27.501002, expected=27.501002
# Iter=92, predicted=27.501002, expected=27.494000
# Iter=93, predicted=27.487151, expected=27.500000
# Iter=94, predicted=27.506223, expected=27.505000
# Iter=95, predicted=27.509921, expected=27.507000
# Iter=96, predicted=27.508418, expected=27.509000
# Iter=97, predicted=27.510617, expected=27.514000
# Iter=98, predicted=27.518695, expected=27.519000
# Iter=99, predicted=27.523543, expected=27.524000
# Iter=100, predicted=27.528400, expected=27.531000
# Iter=101, predicted=27.537357, expected=27.534500
# Iter=102, predicted=27.537332, expected=27.540750
# Iter=103, predicted=27.546353, expected=27.549375
# Iter=104, predicted=27.557329, expected=27.559687
# Iter=105, predicted=27.569042, expected=27.570844
# Iter=106, predicted=27.580825, expected=27.569922
# Iter=107, predicted=27.567966, expected=27.569461
# Iter=108, predicted=27.568525, expected=27.569230
# Iter=109, predicted=27.569072, expected=27.569115
# Iter=110, predicted=27.569036, expected=27.569058
# Iter=111, predicted=27.569018, expected=27.569029
# Iter=112, predicted=27.569009, expected=27.569014
# Iter=113, predicted=27.569005, expected=27.569007
# Iter=114, predicted=27.569002, expected=27.569004
# Iter=115, predicted=27.569001, expected=27.569002
# Iter=116, predicted=27.569001, expected=27.556001
# Iter=117, predicted=27.543284, expected=27.539500
# Iter=118, predicted=27.524017, expected=27.530250
# Iter=119, predicted=27.522655, expected=27.525625
# Iter=120, predicted=27.522354, expected=27.523313
# Iter=121, predicted=27.521725, expected=27.522156
# Iter=122, predicted=27.521362, expected=27.521578
# Iter=123, predicted=27.521181, expected=27.521289
# Iter=124, predicted=27.521091, expected=27.521145
# Iter=125, predicted=27.521045, expected=27.517000
# Iter=126, predicted=27.512967, expected=27.521000
# Iter=127, predicted=27.525129, expected=27.519000
# Iter=128, predicted=27.517039, expected=27.516000
# Iter=129, predicted=27.512976, expected=27.517000
# Iter=130, predicted=27.518225, expected=27.518000
# Iter=131, predicted=27.519071, expected=27.517000
# Iter=132, predicted=27.515924, expected=27.517000
# Iter=133, predicted=27.517003, expected=27.515000
# Iter=134, predicted=27.513091, expected=27.514000
# Iter=135, predicted=27.513123, expected=27.515000
# Iter=136, predicted=27.516124, expected=27.515000
# Iter=137, predicted=27.514997, expected=27.512000
# Iter=138, predicted=27.509018, expected=27.508000
# Iter=139, predicted=27.504239, expected=27.501000
# Iter=140, predicted=27.494498, expected=27.495000
# Iter=141, predicted=27.489675, expected=27.490000
# Iter=142, predicted=27.485746, expected=27.486000
# Iter=143, predicted=27.482626, expected=27.484000
# Iter=144, predicted=27.482484, expected=27.483000
# Iter=145, predicted=27.482313, expected=27.482000
# Iter=146, predicted=27.481168, expected=27.482000
# Iter=147, predicted=27.482098, expected=27.484000
# Iter=148, predicted=27.486004, expected=27.485000
# Iter=149, predicted=27.485877, expected=27.484000
# Iter=150, predicted=27.482876, expected=27.482000
# Iter=151, predicted=27.480047, expected=27.477000
# Iter=152, predicted=27.472258, expected=27.471000
# Iter=153, predicted=27.465479, expected=27.464000
# Iter=154, predicted=27.457694, expected=27.460000
# Iter=155, predicted=27.456727, expected=27.453000
# Iter=156, predicted=27.446688, expected=27.444000
# Iter=157, predicted=27.435741, expected=27.435000
# Iter=158, predicted=27.426984, expected=27.426000
# Iter=159, predicted=27.418080, expected=27.418500
# Iter=160, predicted=27.412047, expected=27.412250
# Iter=161, predicted=27.406944, expected=27.406125
# Iter=162, predicted=27.400807, expected=27.400562
# Iter=163, predicted=27.395728, expected=27.396281
# Iter=164, predicted=27.392666, expected=27.396641
# Iter=165, predicted=27.397473, expected=27.396820
# Iter=166, predicted=27.397182, expected=27.396910
# Iter=167, predicted=27.396972, expected=27.396955
# Iter=168, predicted=27.396986, expected=27.396978
# Iter=169, predicted=27.396993, expected=27.396989
# Iter=170, predicted=27.396996, expected=27.396994
# Iter=171, predicted=27.396998, expected=27.396997
# Iter=172, predicted=27.396999, expected=27.392000
# Iter=173, predicted=27.387112, expected=27.397000
# Iter=174, predicted=27.402143, expected=27.402000
# Iter=175, predicted=27.406876, expected=27.408000
# Iter=176, predicted=27.413378, expected=27.414000
# Iter=177, predicted=27.419328, expected=27.421000
# Iter=178, predicted=27.427258, expected=27.429000
# Iter=179, predicted=27.436186, expected=27.436000
# Iter=180, predicted=27.442110, expected=27.442000
# Iter=181, predicted=27.447134, expected=27.444000
# Iter=182, predicted=27.445320, expected=27.443000
# Iter=183, predicted=27.441635, expected=27.411000
# Iter=184, predicted=27.379654, expected=27.409500
# Iter=185, predicted=27.409697, expected=27.408750
# Iter=186, predicted=27.409616, expected=27.401375
# Iter=187, predicted=27.394270, expected=27.384687
# Iter=188, predicted=27.368773, expected=27.363844
# Iter=189, predicted=27.344649, expected=27.342922
# Iter=190, predicted=27.324304, expected=27.329461
# Iter=191, predicted=27.318343, expected=27.322730
# Iter=192, predicted=27.317823, expected=27.319365
# Iter=193, predicted=27.317054, expected=27.317683
# Iter=194, predicted=27.316527, expected=27.316841
# Iter=195, predicted=27.316264, expected=27.316421
# Iter=196, predicted=27.316132, expected=27.311000
# Iter=197, predicted=27.305759, expected=27.316000
# Iter=198, predicted=27.321185, expected=27.316000
# Iter=199, predicted=27.316006, expected=27.309500
# Iter=200, predicted=27.302904, expected=27.303250
# Iter=201, predicted=27.297465, expected=27.295625
# Iter=202, predicted=27.288792, expected=27.295813
# Iter=203, predicted=27.296679, expected=27.295906
# Iter=204, predicted=27.296352, expected=27.295953
# Iter=205, predicted=27.295985, expected=27.295977
# Iter=206, predicted=27.295993, expected=27.295988
# Iter=207, predicted=27.295996, expected=27.295994
# Iter=208, predicted=27.295998, expected=27.295997
# Iter=209, predicted=27.295999, expected=27.295999
# Iter=210, predicted=27.296000, expected=27.295999
# Iter=211, predicted=27.296000, expected=27.296000
# Iter=212, predicted=27.296000, expected=27.295999
# Iter=213, predicted=27.295999, expected=27.295999
# Iter=214, predicted=27.295999, expected=27.295999
# Iter=215, predicted=27.295999, expected=27.295999
# Iter=216, predicted=27.295999, expected=27.295999
# Iter=217, predicted=27.295999, expected=27.295999
# Iter=218, predicted=27.295999, expected=27.295999
# Iter=219, predicted=27.295999, expected=27.295999
# Iter=220, predicted=27.295999, expected=27.295999
# Iter=221, predicted=27.295999, expected=27.292500
# Iter=222, predicted=27.289076, expected=27.284750
# Iter=223, predicted=27.277346, expected=27.278875
# Iter=224, predicted=27.273686, expected=27.273937
# Iter=225, predicted=27.269774, expected=27.267969
# Iter=226, predicted=27.262659, expected=27.262484
# Iter=227, predicted=27.257656, expected=27.258242
# Iter=228, predicted=27.254654, expected=27.251000
# Iter=229, predicted=27.244391, expected=27.247000
# Iter=230, predicted=27.243655, expected=27.242000
# Iter=231, predicted=27.237656, expected=27.234000
# Iter=232, predicted=27.226618, expected=27.226000
# Iter=233, predicted=27.218817, expected=27.221000
# Iter=234, predicted=27.216894, expected=27.216000
# Iter=235, predicted=27.211743, expected=27.213000
# Iter=236, predicted=27.210556, expected=27.211000
# Iter=237, predicted=27.209433, expected=27.208000
# Iter=238, predicted=27.205309, expected=27.207000
# Iter=239, predicted=27.206269, expected=27.208000
# Iter=240, predicted=27.209172, expected=27.209000
# Iter=241, predicted=27.209975, expected=27.212000
# Iter=242, predicted=27.214836, expected=27.216000
# Iter=243, predicted=27.219714, expected=27.222000
# Iter=244, predicted=27.227524, expected=27.227000
# Iter=245, predicted=27.231397, expected=27.230000
# Iter=246, predicted=27.232396, expected=27.232000
# Iter=247, predicted=27.233567, expected=27.231000
# Iter=248, predicted=27.229778, expected=27.228000
# Iter=249, predicted=27.225021, expected=27.224000
# Iter=250, predicted=27.220286, expected=27.213000
# Iter=251, predicted=27.202585, expected=27.213500
# Iter=252, predicted=27.214735, expected=27.215000
# Iter=253, predicted=27.216966, expected=27.218500
# Iter=254, predicted=27.221824, expected=27.219750
# Iter=255, predicted=27.220724, expected=27.219125
# Iter=256, predicted=27.218284, expected=27.218812
# Iter=257, predicted=27.218479, expected=27.218656
# Iter=258, predicted=27.218549, expected=27.218578
# Iter=259, predicted=27.218524, expected=27.218539
# Iter=260, predicted=27.218512, expected=27.223000
# Iter=261, predicted=27.227369, expected=27.228000
# Iter=262, predicted=27.232667, expected=27.228000
# Iter=263, predicted=27.227535, expected=27.218520
# Iter=264, predicted=27.209008, expected=27.214260
# Iter=265, predicted=27.210572, expected=27.205630
# Iter=266, predicted=27.197855, expected=27.192315
# Iter=267, predicted=27.179929, expected=27.183657
# Iter=268, predicted=27.176273, expected=27.187986
# Iter=269, predicted=27.193292, expected=27.190151
# Iter=270, predicted=27.192461, expected=27.191233
# Iter=271, predicted=27.191976, expected=27.191774
# Iter=272, predicted=27.192145, expected=27.192044
# Iter=273, predicted=27.192230, expected=27.192180
# Iter=274, predicted=27.192273, expected=27.192112
# Iter=275, predicted=27.192026, expected=27.192078
# Iter=276, predicted=27.192042, expected=27.192061
# Iter=277, predicted=27.192050, expected=27.192053
# Iter=278, predicted=27.192047, expected=27.192049
# Iter=279, predicted=27.192046, expected=27.192047
# Iter=280, predicted=27.192045, expected=27.192045
# Iter=281, predicted=27.192045, expected=27.192045
# Iter=282, predicted=27.192045, expected=27.192045
# Iter=283, predicted=27.192044, expected=27.190522
# Iter=284, predicted=27.189033, expected=27.183761
# Iter=285, predicted=27.177225, expected=27.174881
# Iter=286, predicted=27.166608, expected=27.166440
# Iter=287, predicted=27.158955, expected=27.160220
# Iter=288, predicted=27.154985, expected=27.154610
# Iter=289, predicted=27.149839, expected=27.146805
# Iter=290, predicted=27.139750, expected=27.138403
# Iter=291, predicted=27.130845, expected=27.138201
# Iter=292, predicted=27.138800, expected=27.138302
# Iter=293, predicted=27.138811, expected=27.138352
# Iter=294, predicted=27.138406, expected=27.138377
# Iter=295, predicted=27.138395, expected=27.138390
# Iter=296, predicted=27.138399, expected=27.138396
# Iter=297, predicted=27.138401, expected=27.138393
# Iter=298, predicted=27.138389, expected=27.138392
# Iter=299, predicted=27.138390, expected=27.138391
# Root Mean Squared Error (RMSE): 0.003917000431785831
# Mean Absolute Error (MAE): 0.0019727975906066674
# Mean Absolute Percentage Error (MAPE): 0.007201504110397551%
