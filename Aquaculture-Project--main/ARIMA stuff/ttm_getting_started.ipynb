# %% [markdown]
# # Getting started with TinyTimeMixer (TTM)
#
# This notebooke demonstrates the usage of a pre-trained `TinyTimeMixer` model for several multivariate time series forecasting tasks. For details related to model architecture, refer to the [TTM paper](https://arxiv.org/pdf/2401.03955.pdf).
#
# In this example, we will use a pre-trained TTM-512-96 model. That means the TTM model can take an input of 512 time points (`context_length`), and can forecast upto 96 time points (`forecast_length`) in the future. We will use the pre-trained TTM in two settings:
# 1. **Zero-shot**: The pre-trained TTM will be directly used to evaluate on the `test` split of the target data. Note that the TTM was NOT pre-trained on the target data.
# 2. **Few-shot**: The pre-trained TTM will be quickly fine-tuned on only 5% of the `train` split of the target data, and subsequently, evaluated on the `test` part of the target data.
#
# Note: Alternatively, this notebook can be modified to try any other TTM model from a suite of TTM models. For details, visit the [Hugging Face TTM Model Repository](https://huggingface.co/ibm-granite/granite-timeseries-ttm-r2).
#
# 1. IBM Granite TTM-R1 pre-trained models can be found here: [Granite-TTM-R1 Model Card](https://huggingface.co/ibm-granite/granite-timeseries-ttm-r1)
# 2. IBM Granite TTM-R2 pre-trained models can be found here: [Granite-TTM-R2 Model Card](https://huggingface.co/ibm-granite/granite-timeseries-ttm-r2)
# 3. Research-use (non-commercial use only) TTM-R2 pre-trained models can be found here: [Research-Use-TTM-R2](https://huggingface.co/ibm-research/ttm-research-r2)

# %% [markdown]
# ## Install `tsfm`
# **[Optional for Local Run / Mandatory for Google Colab]**
# Run the below cell to install `tsfm`. Skip if already installed.

# %%
# Install the tsfm library
! pip3 install "tsfm_public[notebooks] @ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14" --break-system-packages
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14 (from tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14)
#   Cloning https://github.com/ibm-granite/granite-tsfm.git (to revision v0.2.14) to /tmp/pip-install-p5qz2dz6/tsfm-public_5c84640645a1444d8aa12500310b9f56
#   Running command git clone --filter=blob:none --quiet https://github.com/ibm-granite/granite-tsfm.git /tmp/pip-install-p5qz2dz6/tsfm-public_5c84640645a1444d8aa12500310b9f56
#   Running command git checkout -q fea9e7e578065d38491f777422a43cea71564994
#   Resolved https://github.com/ibm-granite/granite-tsfm.git to commit fea9e7e578065d38491f777422a43cea71564994
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pandas>=2.2.0 in /home/trungnt657/.local/lib/python3.12/site-packages (from tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (2.2.3)
# Requirement already satisfied: scikit-learn in /home/trungnt657/.local/lib/python3.12/site-packages (from tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (1.6.0)
# Collecting transformers>=4.38.0 (from transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14)
#   Downloading transformers-4.48.3-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 389.0 kB/s eta 0:00:00 0:00:01
# Collecting datasets (from tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14)
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Collecting deprecated (from tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14)
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting urllib3<2,>=1.26.19 (from tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14)
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 1.3 MB/s eta 0:00:00
# Collecting numpy<2 (from tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Collecting jupyter (from tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14)
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: matplotlib in /home/trungnt657/.local/lib/python3.12/site-packages (from tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (3.9.2)
# Collecting ipywidgets (from tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14)
#   Downloading ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Collecting plotly (from tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14)
#   Downloading plotly-6.0.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting kaleido (from tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14)
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: tensorboard in /home/trungnt657/.local/lib/python3.12/site-packages (from tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (2.18.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/trungnt657/.local/lib/python3.12/site-packages (from pandas>=2.2.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=2.2.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/trungnt657/.local/lib/python3.12/site-packages (from pandas>=2.2.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (2024.2)
# Requirement already satisfied: filelock in /home/trungnt657/.local/lib/python3.12/site-packages (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (3.16.1)
# Collecting huggingface-hub<1.0,>=0.24.0 (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14)
#   Downloading huggingface_hub-0.28.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (6.0.1)
# Collecting regex!=2019.12.17 (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14)
#   Downloading regex-2024.11.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (2.31.0)
# Collecting tokenizers<0.22,>=0.21 (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14)
#   Downloading tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting safetensors>=0.4.1 (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14)
#   Downloading safetensors-0.5.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: tqdm>=4.27 in /home/trungnt657/.local/lib/python3.12/site-packages (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (4.67.1)
# Requirement already satisfied: torch>=2.0 in /home/trungnt657/.local/lib/python3.12/site-packages (from transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (2.5.1)
# Collecting accelerate>=0.26.0 (from transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14)
#   Downloading accelerate-1.3.0-py3-none-any.whl.metadata (19 kB)
# Collecting pyarrow>=15.0.0 (from datasets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14)
#   Downloading pyarrow-19.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting requests (from transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting xxhash (from datasets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14)
#   Downloading xxhash-3.5.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14)
#   Downloading multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Collecting aiohttp (from datasets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14)
#   Downloading aiohttp-3.11.12-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/trungnt657/.local/lib/python3.12/site-packages (from deprecated->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (1.17.0)
# Requirement already satisfied: comm>=0.1.3 in /home/trungnt657/.local/lib/python3.12/site-packages (from ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /home/trungnt657/.local/lib/python3.12/site-packages (from ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (8.30.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/trungnt657/.local/lib/python3.12/site-packages (from ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (5.14.3)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14)
#   Downloading widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.12 (from ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14)
#   Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: notebook in /home/trungnt657/.local/lib/python3.12/site-packages (from jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (7.3.0)
# Collecting jupyter-console (from jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14)
#   Downloading jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: nbconvert in /home/trungnt657/.local/lib/python3.12/site-packages (from jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (7.16.4)
# Requirement already satisfied: ipykernel in /home/trungnt657/.local/lib/python3.12/site-packages (from jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (6.29.5)
# Requirement already satisfied: jupyterlab in /home/trungnt657/.local/lib/python3.12/site-packages (from jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (4.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/trungnt657/.local/lib/python3.12/site-packages (from matplotlib->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/trungnt657/.local/lib/python3.12/site-packages (from matplotlib->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/trungnt657/.local/lib/python3.12/site-packages (from matplotlib->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/trungnt657/.local/lib/python3.12/site-packages (from matplotlib->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (1.4.7)
# Requirement already satisfied: pillow>=8 in /home/trungnt657/.local/lib/python3.12/site-packages (from matplotlib->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (3.1.1)
# Collecting narwhals>=1.15.1 (from plotly->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14)
#   Downloading narwhals-1.26.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: scipy>=1.6.0 in /home/trungnt657/.local/lib/python3.12/site-packages (from scikit-learn->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/trungnt657/.local/lib/python3.12/site-packages (from scikit-learn->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/trungnt657/.local/lib/python3.12/site-packages (from scikit-learn->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (3.5.0)
# Requirement already satisfied: absl-py>=0.4 in /home/trungnt657/.local/lib/python3.12/site-packages (from tensorboard->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /home/trungnt657/.local/lib/python3.12/site-packages (from tensorboard->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (1.68.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/trungnt657/.local/lib/python3.12/site-packages (from tensorboard->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /home/trungnt657/.local/lib/python3.12/site-packages (from tensorboard->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (5.29.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/lib/python3/dist-packages (from tensorboard->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (68.1.2)
# Requirement already satisfied: six>1.9 in /usr/lib/python3/dist-packages (from tensorboard->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/trungnt657/.local/lib/python3.12/site-packages (from tensorboard->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/trungnt657/.local/lib/python3.12/site-packages (from tensorboard->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (3.1.3)
# Requirement already satisfied: psutil in /usr/lib/python3/dist-packages (from accelerate>=0.26.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (5.9.8)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp->datasets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14)
#   Downloading aiohappyeyeballs-2.4.6-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14)
#   Using cached aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/lib/python3/dist-packages (from aiohttp->datasets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (23.2.0)
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14)
#   Using cached frozenlist-1.5.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14)
#   Using cached multidict-6.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting propcache>=0.2.0 (from aiohttp->datasets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14)
#   Using cached propcache-0.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.2 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp->datasets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14)
#   Using cached yarl-1.18.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (69 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/lib/python3/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (4.10.0)
# Requirement already satisfied: decorator in /home/trungnt657/.local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/trungnt657/.local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/trungnt657/.local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /home/trungnt657/.local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/trungnt657/.local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in /usr/lib/python3/dist-packages (from ipython>=6.1.0->ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (2.17.2)
# Requirement already satisfied: stack_data in /home/trungnt657/.local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (0.6.3)
# Collecting charset-normalizer<4,>=2 (from requests->transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14)
#   Downloading charset_normalizer-3.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->transformers>=4.38.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (2023.11.17)
# Requirement already satisfied: networkx in /home/trungnt657/.local/lib/python3.12/site-packages (from torch>=2.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch>=2.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/trungnt657/.local/lib/python3.12/site-packages (from torch>=2.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/trungnt657/.local/lib/python3.12/site-packages (from torch>=2.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/trungnt657/.local/lib/python3.12/site-packages (from torch>=2.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/trungnt657/.local/lib/python3.12/site-packages (from torch>=2.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/trungnt657/.local/lib/python3.12/site-packages (from torch>=2.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/trungnt657/.local/lib/python3.12/site-packages (from torch>=2.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/trungnt657/.local/lib/python3.12/site-packages (from torch>=2.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/trungnt657/.local/lib/python3.12/site-packages (from torch>=2.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/trungnt657/.local/lib/python3.12/site-packages (from torch>=2.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/trungnt657/.local/lib/python3.12/site-packages (from torch>=2.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/trungnt657/.local/lib/python3.12/site-packages (from torch>=2.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/trungnt657/.local/lib/python3.12/site-packages (from torch>=2.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /home/trungnt657/.local/lib/python3.12/site-packages (from torch>=2.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/trungnt657/.local/lib/python3.12/site-packages (from torch>=2.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/trungnt657/.local/lib/python3.12/site-packages (from sympy==1.13.1->torch>=2.0->transformers[torch]>=4.38.0->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/lib/python3/dist-packages (from werkzeug>=1.0.1->tensorboard->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (2.1.5)
# Requirement already satisfied: debugpy>=1.6.5 in /home/trungnt657/.local/lib/python3.12/site-packages (from ipykernel->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (1.8.9)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/trungnt657/.local/lib/python3.12/site-packages (from ipykernel->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/trungnt657/.local/lib/python3.12/site-packages (from ipykernel->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (5.7.2)
# Requirement already satisfied: nest-asyncio in /home/trungnt657/.local/lib/python3.12/site-packages (from ipykernel->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (1.6.0)
# Requirement already satisfied: pyzmq>=24 in /home/trungnt657/.local/lib/python3.12/site-packages (from ipykernel->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in /home/trungnt657/.local/lib/python3.12/site-packages (from ipykernel->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (6.4.2)
# Requirement already satisfied: async-lru>=1.0.0 in /home/trungnt657/.local/lib/python3.12/site-packages (from jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (2.0.4)
# Requirement already satisfied: httpx~=0.28.0 in /home/trungnt657/.local/lib/python3.12/site-packages (from jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (0.28.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/trungnt657/.local/lib/python3.12/site-packages (from jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/trungnt657/.local/lib/python3.12/site-packages (from jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /home/trungnt657/.local/lib/python3.12/site-packages (from jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /home/trungnt657/.local/lib/python3.12/site-packages (from jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /home/trungnt657/.local/lib/python3.12/site-packages (from nbconvert->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /home/trungnt657/.local/lib/python3.12/site-packages (from nbconvert->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (6.2.0)
# Requirement already satisfied: defusedxml in /home/trungnt657/.local/lib/python3.12/site-packages (from nbconvert->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/trungnt657/.local/lib/python3.12/site-packages (from nbconvert->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/trungnt657/.local/lib/python3.12/site-packages (from nbconvert->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /home/trungnt657/.local/lib/python3.12/site-packages (from nbconvert->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (0.10.1)
# Requirement already satisfied: nbformat>=5.7 in /home/trungnt657/.local/lib/python3.12/site-packages (from nbconvert->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/trungnt657/.local/lib/python3.12/site-packages (from nbconvert->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (1.5.1)
# Requirement already satisfied: tinycss2 in /home/trungnt657/.local/lib/python3.12/site-packages (from nbconvert->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (1.4.0)
# Requirement already satisfied: webencodings in /home/trungnt657/.local/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (0.5.1)
# Requirement already satisfied: anyio in /home/trungnt657/.local/lib/python3.12/site-packages (from httpx~=0.28.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in /home/trungnt657/.local/lib/python3.12/site-packages (from httpx~=0.28.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/trungnt657/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx~=0.28.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/trungnt657/.local/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/lib/python3/dist-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/trungnt657/.local/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /home/trungnt657/.local/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/trungnt657/.local/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /home/trungnt657/.local/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/trungnt657/.local/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (0.21.1)
# Requirement already satisfied: send2trash>=1.8.2 in /home/trungnt657/.local/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/trungnt657/.local/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/trungnt657/.local/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /usr/lib/python3/dist-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (2.10.3)
# Requirement already satisfied: json5>=0.9.0 in /home/trungnt657/.local/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (0.10.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/trungnt657/.local/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (4.23.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/trungnt657/.local/lib/python3.12/site-packages (from nbformat>=5.7->nbconvert->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (2.21.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/trungnt657/.local/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (0.7.0)
# Requirement already satisfied: wcwidth in /home/trungnt657/.local/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in /home/trungnt657/.local/lib/python3.12/site-packages (from beautifulsoup4->nbconvert->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (2.6)
# Requirement already satisfied: executing>=1.2.0 in /home/trungnt657/.local/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/trungnt657/.local/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (2.4.1)
# Requirement already satisfied: pure-eval in /home/trungnt657/.local/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (0.2.3)
# Requirement already satisfied: sniffio>=1.1 in /home/trungnt657/.local/lib/python3.12/site-packages (from anyio->httpx~=0.28.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /home/trungnt657/.local/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (21.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/trungnt657/.local/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/trungnt657/.local/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/trungnt657/.local/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (0.22.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/trungnt657/.local/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /home/trungnt657/.local/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/trungnt657/.local/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (0.1.1)
# Requirement already satisfied: fqdn in /home/trungnt657/.local/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (1.5.1)
# Requirement already satisfied: isoduration in /home/trungnt657/.local/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/lib/python3/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (2.0)
# Requirement already satisfied: uri-template in /home/trungnt657/.local/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/trungnt657/.local/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in /home/trungnt657/.local/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (1.17.1)
# Requirement already satisfied: pycparser in /home/trungnt657/.local/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /home/trungnt657/.local/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/trungnt657/.local/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->tsfm_public@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14->tsfm_public[notebooks]@ git+https://github.com/ibm-granite/granite-tsfm.git@v0.2.14) (2.9.0.20241003)
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 11.0 MB/s eta 0:00:0000:0100:01
# Downloading transformers-4.48.3-py3-none-any.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 14.4 MB/s eta 0:00:0000:0100:01
# Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 3.7 MB/s eta 0:00:0000:01
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 24.0 MB/s eta 0:00:00
# Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Downloading ipywidgets-8.1.5-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 6.3 MB/s eta 0:00:00
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 9.9 MB/s eta 0:00:00:00:0100:01
# Downloading plotly-6.0.0-py3-none-any.whl (14.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 10.3 MB/s eta 0:00:0000:0100:01
# Downloading accelerate-1.3.0-py3-none-any.whl (336 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.6/336.6 kB 7.7 MB/s eta 0:00:00ta 0:00:01
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.1 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 14.0 MB/s eta 0:00:00
# Downloading aiohttp-3.11.12-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 10.0 MB/s eta 0:00:00a 0:00:01
# Downloading huggingface_hub-0.28.1-py3-none-any.whl (464 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 464.1/464.1 kB 21.8 MB/s eta 0:00:00
# Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.4/214.4 kB 14.1 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py312-none-any.whl (146 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.7/146.7 kB 9.7 MB/s eta 0:00:00
# Downloading narwhals-1.26.0-py3-none-any.whl (306 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.6/306.6 kB 9.0 MB/s eta 0:00:00
# Downloading pyarrow-19.0.0-cp312-cp312-manylinux_2_28_x86_64.whl (42.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 7.3 MB/s eta 0:00:0000:01m00:01
# Downloading regex-2024.11.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (796 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 796.9/796.9 kB 10.0 MB/s eta 0:00:0000:0100:01
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 4.2 MB/s eta 0:00:00
# Downloading safetensors-0.5.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (461 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.0/462.0 kB 7.9 MB/s eta 0:00:00ta 0:00:01
# Downloading tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 10.0 MB/s eta 0:00:0000:0100:01
# Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 14.0 MB/s eta 0:00:00a 0:00:01
# Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Downloading xxhash-3.5.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 11.5 MB/s eta 0:00:00
# Downloading aiohappyeyeballs-2.4.6-py3-none-any.whl (14 kB)
# Using cached aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Downloading charset_normalizer-3.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (145 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.3/145.3 kB 5.3 MB/s eta 0:00:00
# Using cached frozenlist-1.5.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (283 kB)
# Using cached multidict-6.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (131 kB)
# Using cached propcache-0.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (243 kB)
# Using cached yarl-1.18.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (336 kB)
# Building wheels for collected packages: tsfm_public
#   Building wheel for tsfm_public (pyproject.toml) ... done
#   Created wheel for tsfm_public: filename=tsfm_public-0.2.14-py3-none-any.whl size=2334084 sha256=dbd1a14a4ee3d9003ca952ca99e0f9939b04afaf4a349ca4b770115556248fd3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9e6vt1_b/wheels/26/56/dc/95786bf9d4ccf08770fb187110a67867aa10de8aa1e8e50b2a
# Successfully built tsfm_public
# Installing collected packages: kaleido, xxhash, widgetsnbextension, urllib3, safetensors, regex, pyarrow, propcache, numpy, narwhals, multidict, jupyterlab-widgets, fsspec, frozenlist, dill, deprecated, charset-normalizer, aiohappyeyeballs, yarl, requests, plotly, multiprocess, aiosignal, huggingface-hub, aiohttp, tokenizers, ipywidgets, accelerate, transformers, jupyter-console, datasets, tsfm_public, jupyter
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# Successfully installed accelerate-1.3.0 aiohappyeyeballs-2.4.6 aiohttp-3.11.12 aiosignal-1.3.2 charset-normalizer-3.4.1 datasets-3.2.0 deprecated-1.2.18 dill-0.3.8 frozenlist-1.5.0 fsspec-2024.9.0 huggingface-hub-0.28.1 ipywidgets-8.1.5 jupyter-1.1.1 jupyter-console-6.6.3 jupyterlab-widgets-3.0.13 kaleido-0.2.1 multidict-6.1.0 multiprocess-0.70.16 narwhals-1.26.0 numpy-1.26.4 plotly-6.0.0 propcache-0.2.1 pyarrow-19.0.0 regex-2024.11.6 requests-2.32.3 safetensors-0.5.2 tokenizers-0.21.0 transformers-4.48.3 tsfm_public-0.2.14 urllib3-1.26.20 widgetsnbextension-4.0.13 xxhash-3.5.0 yarl-1.18.3

# %% [markdown]
# ## Imports

# %%
import math
import os
import tempfile

import pandas as pd
from torch.optim import AdamW
from torch.optim.lr_scheduler import OneCycleLR
from transformers import EarlyStoppingCallback, Trainer, TrainingArguments, set_seed
from transformers.integrations import INTEGRATION_TO_CALLBACK

from tsfm_public import TimeSeriesPreprocessor, TrackingCallback, count_parameters, get_datasets
from tsfm_public.toolkit.get_model import get_model
from tsfm_public.toolkit.lr_finder import optimal_lr_finder
from tsfm_public.toolkit.visualization import plot_predictions
# Out:
# 2025-02-17 17:22:59.181071: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-17 17:22:59.198357: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1739787779.218436   16243 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1739787779.225171   16243 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-17 17:22:59.248819: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import warnings


# Suppress all warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Important arguments

# %%
# Set seed for reproducibility
SEED = 42
set_seed(SEED)

# TTM Model path. The default model path is Granite-R2. Below, you can choose other TTM releases.
TTM_MODEL_PATH = "ibm-granite/granite-timeseries-ttm-r2"
# TTM_MODEL_PATH = "ibm-granite/granite-timeseries-ttm-r1"
# TTM_MODEL_PATH = "ibm-research/ttm-research-r2"

# Context length, Or Length of the history.
# Currently supported values are: 512/1024/1536 for Granite-TTM-R2 and Research-Use-TTM-R2, and 512/1024 for Granite-TTM-R1
CONTEXT_LENGTH = 1024

# Granite-TTM-R2 supports forecast length upto 720 and Granite-TTM-R1 supports forecast length upto 96
PREDICTION_LENGTH = 8

TARGET_DATASET = "etth1"
dataset_path = "https://github.com/phucngvinuni/Aquaculture-Project-/blob/main/ARIMA%20stuff/Pretreated%20data.csv"


# Results dir
OUT_DIR = "ttm_finetuned_models/"

# %% [markdown]
# # Data processing

# %%
# Dataset
TARGET_DATASET = "etth1"
dataset_path = "./Pretreated data.csv"
timestamp_column = "date"
id_columns = []  # mention the ids that uniquely identify a time-series.

target_columns = ["Temp(degC)", "Air_temp(degC)", "Salinity(PSU)", "pH", "DO(mg/l)", "precipitation(mm)"]
split_config = {
    "train": [0, 10000],
    "valid": [10000, 15000],
    "test": [
        15000,
        20000,
    ],
}
# Understanding the split config -- slides

data = pd.read_csv(
    dataset_path,
    parse_dates=[timestamp_column],
)

column_specifiers = {
    "timestamp_column": timestamp_column,
    "id_columns": id_columns,
    "target_columns": target_columns,
    "control_columns": [],
}

# %% [markdown]
# ## Zero-shot evaluation method

# %%
def zeroshot_eval(dataset_name, batch_size, context_length=512, forecast_length=96, split_config = split_config):
    # Get data

    tsp = TimeSeriesPreprocessor(
        **column_specifiers,
        context_length=context_length,
        prediction_length=forecast_length,
        scaling=True,
        encode_categorical=False,
        scaler_type="standard",
    )

    dset_train, dset_valid, dset_test = get_datasets(tsp, data, split_config)

    # Load model
    zeroshot_model = get_model(TTM_MODEL_PATH, context_length=context_length, prediction_length=forecast_length)

    temp_dir = tempfile.mkdtemp()
    # zeroshot_trainer
    zeroshot_trainer = Trainer(
        model=zeroshot_model,
        args=TrainingArguments(
            output_dir=temp_dir,
            per_device_eval_batch_size=batch_size,
            seed=SEED,
            report_to="none",
        ),
    )
    # evaluate = zero-shot performance
    print("+" * 20, "Test MSE zero-shot", "+" * 20)
    zeroshot_output = zeroshot_trainer.evaluate(dset_test)
    print(zeroshot_output)

    # get predictions

    predictions_dict = zeroshot_trainer.predict(dset_test)

    predictions_np = predictions_dict.predictions[0]

    print(predictions_np.shape)

    # get backbone embeddings (if needed for further analysis)

    backbone_embedding = predictions_dict.predictions[1]

    print(backbone_embedding.shape)

    # plot
    plot_predictions(
        model=zeroshot_trainer.model,
        dset=dset_test,
        plot_dir=os.path.join(OUT_DIR, dataset_name),
        plot_prefix="test_zeroshot",
        indices=[685, 118, 902, 1984, 894, 967, 304, 57, 265, 1015],
        channel=0,
    )

# %% [markdown]
# # Zeroshot

# %%
zeroshot_eval(
    dataset_name=TARGET_DATASET, context_length=CONTEXT_LENGTH, forecast_length=PREDICTION_LENGTH, batch_size=64
)
# Out:
# INFO:p-837:t-140445363007616:get_model.py:get_model:Loading model from: ibm-granite/granite-timeseries-ttm-r2
# INFO:p-837:t-140445363007616:get_model.py:get_model:Selected prediction_length = 96
# config.json:   0%|          | 0.00/1.57k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/11.9M [00:00<?, ?B/s]
# INFO:p-837:t-140445363007616:get_model.py:get_model:Model loaded successfully!
# INFO:p-837:t-140445363007616:get_model.py:get_model:[TTM] context_len = 1024, forecast_len = 96
# ++++++++++++++++++++ Test MSE zero-shot ++++++++++++++++++++
# {'eval_loss': 0.3574405312538147, 'eval_model_preparation_time': 0.0017, 'eval_runtime': 25.1501, 'eval_samples_per_second': 195.029, 'eval_steps_per_second': 3.062}
# (4905, 96, 6)
# (4905, 6, 8, 384)

# %% [markdown]
#  ## Few-shot finetune and evaluation method

# %%
def fewshot_finetune_eval(
    dataset_name,
    batch_size,
    learning_rate=None,
    context_length=512,
    forecast_length=PREDICTION_LENGTH,
    fewshot_percent=5,
    freeze_backbone=True,
    num_epochs=100,
    save_dir=OUT_DIR,
    loss="mse",
    quantile=0.5,
):
    out_dir = os.path.join(save_dir, dataset_name)

    print("-" * 20, f"Running few-shot {fewshot_percent}%", "-" * 20)

    # Data prep: Get dataset

    tsp = TimeSeriesPreprocessor(
        **column_specifiers,
        context_length=context_length,
        prediction_length=forecast_length,
        scaling=True,
        encode_categorical=False,
        scaler_type="standard",
    )

    dset_train, dset_val, dset_test = get_datasets(
        tsp, data, split_config, fewshot_fraction=fewshot_percent / 100, fewshot_location="first"
    )

    # change head dropout to 0.7 for ett datasets
    if "ett" in dataset_name:
        finetune_forecast_model = get_model(
            TTM_MODEL_PATH,
            context_length=context_length,
            prediction_length=forecast_length,
            head_dropout=0.7,
            loss=loss,
            # quantile=quantile,
        )
    else:
        finetune_forecast_model = get_model(
            TTM_MODEL_PATH,
            context_length=context_length,
            prediction_length=forecast_length,
            loss=loss,
            # quantile=quantile,
        )

    if freeze_backbone:
        print(
            "Number of params before freezing backbone",
            count_parameters(finetune_forecast_model),
        )

        # Freeze the backbone of the model
        for param in finetune_forecast_model.backbone.parameters():
            param.requires_grad = False

        # Count params
        print(
            "Number of params after freezing the backbone",
            count_parameters(finetune_forecast_model),
        )

    # Find optimal learning rate
    # Use with caution: Set it manually if the suggested learning rate is not suitable
    if learning_rate is None:
        learning_rate, finetune_forecast_model = optimal_lr_finder(
            finetune_forecast_model,
            dset_train,
            batch_size=batch_size,
        )
        print("OPTIMAL SUGGESTED LEARNING RATE =", learning_rate)

    print(f"Using learning rate = {learning_rate}")
    finetune_forecast_args = TrainingArguments(
        output_dir=os.path.join(out_dir, "output"),
        overwrite_output_dir=True,
        learning_rate=learning_rate,
        num_train_epochs=num_epochs,
        do_eval=True,
        evaluation_strategy="epoch",
        per_device_train_batch_size=batch_size,
        per_device_eval_batch_size=batch_size,
        dataloader_num_workers=8,
        report_to="none",
        save_strategy="epoch",
        logging_strategy="epoch",
        save_total_limit=1,
        logging_dir=os.path.join(out_dir, "logs"),  # Make sure to specify a logging directory
        load_best_model_at_end=True,  # Load the best model when training ends
        metric_for_best_model="eval_loss",  # Metric to monitor for early stopping
        greater_is_better=False,  # For loss
        seed=SEED,
    )

    # Create the early stopping callback
    early_stopping_callback = EarlyStoppingCallback(
        early_stopping_patience=10,  # Number of epochs with no improvement after which to stop
        early_stopping_threshold=1e-5,  # Minimum improvement required to consider as improvement
    )
    tracking_callback = TrackingCallback()

    # Optimizer and scheduler
    optimizer = AdamW(finetune_forecast_model.parameters(), lr=learning_rate)
    scheduler = OneCycleLR(
        optimizer,
        learning_rate,
        epochs=num_epochs,
        steps_per_epoch=math.ceil(len(dset_train) / (batch_size)),
    )

    finetune_forecast_trainer = Trainer(
        model=finetune_forecast_model,
        args=finetune_forecast_args,
        train_dataset=dset_train,
        eval_dataset=dset_val,
        callbacks=[early_stopping_callback, tracking_callback],
        optimizers=(optimizer, scheduler),
    )
    finetune_forecast_trainer.remove_callback(INTEGRATION_TO_CALLBACK["codecarbon"])

    # Fine tune
    finetune_forecast_trainer.train()

    # Evaluation
    print("+" * 20, f"Test MSE after few-shot {fewshot_percent}% fine-tuning", "+" * 20)

    finetune_forecast_trainer.model.loss = "mse"  # fixing metric to mse for evaluation

    fewshot_output = finetune_forecast_trainer.evaluate(dset_test)
    print(fewshot_output)
    print("+" * 60)

    # get predictions

    predictions_dict = finetune_forecast_trainer.predict(dset_test)

    predictions_np = predictions_dict.predictions[0]

    print(predictions_np.shape)

    # get backbone embeddings (if needed for further analysis)

    backbone_embedding = predictions_dict.predictions[1]

    print(backbone_embedding.shape)

    # plot
    plot_predictions(
        model=finetune_forecast_trainer.model,
        dset=dset_test,
        plot_dir=os.path.join(OUT_DIR, dataset_name),
        plot_prefix="test_fewshot",
        indices=[685, 118, 902, 1984, 894, 967, 304, 57, 265, 1015],
        channel=0,
    )

# %% [markdown]
# ### Few-shot 5%

# %%
fewshot_finetune_eval(
    dataset_name=TARGET_DATASET,
    context_length=512,
    forecast_length=4,
    batch_size=64,
    fewshot_percent=5,
    learning_rate=0.001,
)
# Out:
# INFO:p-16243:t-139859228541056:get_model.py:get_model:Loading model from: ibm-granite/granite-timeseries-ttm-r2
# INFO:p-16243:t-139859228541056:get_model.py:get_model:Selected prediction_length = 96
# WARNING:p-16243:t-139859228541056:get_model.py:get_model:Requested `prediction_length` (4) is not exactly equal to any of the available TTM prediction lengths.
#                     Hence, TTM will forecast using the `prediction_filter_length` argument to provide the requested prediction length.
#                     Supported context lengths (CL) and forecast/prediction lengths (FL) for Model Card: ibm-granite/granite-timeseries-ttm-r2 are
#                     {'CL': [512, 1024, 1536], 'FL': [96, 192, 336, 720]}
# -------------------- Running few-shot 5% --------------------
# INFO:p-16243:t-139859228541056:get_model.py:get_model:Model loaded successfully!
# INFO:p-16243:t-139859228541056:get_model.py:get_model:[TTM] context_len = 512, forecast_len = 96
# Number of params before freezing backbone 805280
# Number of params after freezing the backbone 289696
# Using learning rate = 0.001
#     <div>
#
#       <progress value='88' max='800' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 88/800 00:19 < 02:40, 4.45 it/s, Epoch 11/100]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.042700</td>
#       <td>0.011859</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.042300</td>
#       <td>0.012470</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.036800</td>
#       <td>0.012989</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.030900</td>
#       <td>0.013391</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.031300</td>
#       <td>0.013693</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.031800</td>
#       <td>0.013674</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.020400</td>
#       <td>0.013423</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.018500</td>
#       <td>0.013646</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.017000</td>
#       <td>0.013934</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.014400</td>
#       <td>0.014148</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.013800</td>
#       <td>0.014079</td>
#     </tr>
#   </tbody>
# </table><p>
# [TrackingCallback] Mean Epoch Time = 0.41500392827120697 seconds, Total Train Time = 19.769083261489868
# ++++++++++++++++++++ Test MSE after few-shot 5% fine-tuning ++++++++++++++++++++
# {'eval_loss': 0.011856278404593468, 'eval_runtime': 1.3462, 'eval_samples_per_second': 3711.997, 'eval_steps_per_second': 58.685, 'epoch': 11.0}
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# (4997, 4, 6)
# (4997, 6, 8, 192)

# %% [markdown]
# # Fewshot with quantile loss (We can use pinball loss to generate different quantiles as required)

# %%
fewshot_finetune_eval(
    dataset_name=TARGET_DATASET,
    context_length=CONTEXT_LENGTH,
    forecast_length=PREDICTION_LENGTH,
    batch_size=64,
    fewshot_percent=5,
    learning_rate=0.001,
    loss="pinball",
    quantile=0.5,
)
# Out:
# INFO:p-16243:t-139859228541056:get_model.py:get_model:Loading model from: ibm-granite/granite-timeseries-ttm-r2
# INFO:p-16243:t-139859228541056:get_model.py:get_model:Selected prediction_length = 96
# WARNING:p-16243:t-139859228541056:get_model.py:get_model:Requested `prediction_length` (8) is not exactly equal to any of the available TTM prediction lengths.
#                     Hence, TTM will forecast using the `prediction_filter_length` argument to provide the requested prediction length.
#                     Supported context lengths (CL) and forecast/prediction lengths (FL) for Model Card: ibm-granite/granite-timeseries-ttm-r2 are
#                     {'CL': [512, 1024, 1536], 'FL': [96, 192, 336, 720]}
# -------------------- Running few-shot 5% --------------------
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 fewshot_finetune_eval(
#       2     dataset_name=TARGET_DATASET,
#       3     context_length=CONTEXT_LENGTH,
#       4     forecast_length=PREDICTION_LENGTH,
#       5     batch_size=64,
#       6     fewshot_percent=5,
#       7     learning_rate=0.001,
#       8     loss="pinball",
#       9     quantile=0.5,
#      10 )
#
# Cell In[24], line 35, in fewshot_finetune_eval(dataset_name, batch_size, learning_rate, context_length, forecast_length, fewshot_percent, freeze_backbone, num_epochs, save_dir, loss, quantile)
#      33 # change head dropout to 0.7 for ett datasets
#      34 if "ett" in dataset_name:
# ---> 35     finetune_forecast_model = get_model(
#      36         TTM_MODEL_PATH,
#      37         context_length=context_length,
#      38         prediction_length=forecast_length,
#      39         head_dropout=0.7,
#      40         loss=loss,
#      41         # quantile=quantile,
#      42     )
#      43 else:
#      44     finetune_forecast_model = get_model(
#      45         TTM_MODEL_PATH,
#      46         context_length=context_length,
#    (...)
#      49         # quantile=quantile,
#      50     )
#
# File ~/.local/lib/python3.12/site-packages/tsfm_public/toolkit/get_model.py:155, in get_model(model_path, model_name, context_length, prediction_length, freq_prefix_tuning, **kwargs)
#     149         raise ValueError(
#     150             f"Model not found, possibly because of wrong context_length. Supported context lengths (CL) and forecast/prediction lengths (FL) for Model Card: {model_path} are {SUPPORTED_LENGTHS[model_path_type]}"
#     151         )
#     153 # Load model
# --> 155 model = TinyTimeMixerForPrediction.from_pretrained(
#     156     model_path,
#     157     revision=ttm_model_revision,
#     158     prediction_filter_length=prediction_filter_length,
#     159     **kwargs,
#     160 )
#     162 LOGGER.info("Model loaded successfully!")
#     163 LOGGER.info(
#     164     f"[TTM] context_len = {model.config.context_length}, forecast_len = {model.config.prediction_length}"
#     165 )
#
# File ~/.local/lib/python3.12/site-packages/transformers/modeling_utils.py:4111, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4105     config = cls._autoset_attn_implementation(
#    4106         config, use_flash_attention_2=use_flash_attention_2, torch_dtype=torch_dtype, device_map=device_map
#    4107     )
#    4109 with ContextManagers(init_contexts):
#    4110     # Let's make sure we don't run the init function of buffer modules
# -> 4111     model = cls(config, *model_args, **model_kwargs)
#    4113 # make sure we use the model's config since the __init__ call might have copied it
#    4114 config = model.config
#
# File ~/.local/lib/python3.12/site-packages/tsfm_public/models/tinytimemixer/modeling_tinytimemixer.py:1754, in TinyTimeMixerForPrediction.__init__(self, config)
#    1749 if config.use_decoder:
#    1750     self.decoder = TinyTimeMixerDecoder(config)
#    1752 self.head = TinyTimeMixerForPredictionHead(
#    1753     config=config,
# -> 1754     distribution_output=self.distribution_output,
#    1755 )
#    1757 # Initialize weights and apply final processing
#    1758 if config.post_init:
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1931, in Module.__getattr__(self, name)
#    1929     if name in modules:
#    1930         return modules[name]
# -> 1931 raise AttributeError(
#    1932     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1933 )
#
# AttributeError: 'TinyTimeMixerForPrediction' object has no attribute 'distribution_output'

# %% [markdown]
# ## Example: TTM for other forecast horizon lengths and context lengths
#
#
# **Context length, Or Length of the history:** Currently supported values are: 512/1024/1536 for Granite-TTM-R2 and Research-Use-TTM-R2, and 512/1024 for Granite-TTM-R1
#
# **Forecast length, Or prediction length:** Granite-TTM-R2 supports forecast length upto 720 and Granite-TTM-R1 supports forecast length upto 96

# %% [markdown]
# ### Zero-shot

# %%
zeroshot_eval(dataset_name=TARGET_DATASET, context_length=1024, forecast_length=48, batch_size=64)
# Out:
# WARNING:/usr/local/lib/python3.11/dist-packages/tsfm_public/toolkit/get_model.py:Requested `prediction_length` (48) is not exactly equal to any of the available TTM prediction lengths.
#                     Hence, TTM will forecast using the `prediction_filter_length` argument to provide the requested prediction length.
#                     Supported context lengths (CL) and forecast/prediction lengths (FL) for Model Card: ibm-granite/granite-timeseries-ttm-r2 are
#                     {'CL': [512, 1024, 1536], 'FL': [96, 192, 336, 720]}
# config.json:   0%|          | 0.00/1.57k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/11.9M [00:00<?, ?B/s]
# ++++++++++++++++++++ Test MSE zero-shot ++++++++++++++++++++
# {'eval_loss': 0.23203226923942566, 'eval_model_preparation_time': 0.0037, 'eval_runtime': 57.2183, 'eval_samples_per_second': 86.563, 'eval_steps_per_second': 1.363}
# (4953, 48, 6)
# (4953, 6, 8, 384)

# %% [markdown]
# ### Few-shot 5%

# %%
fewshot_finetune_eval(
    dataset_name=TARGET_DATASET,
    context_length=1536,
    forecast_length=8,
    batch_size=64,
    fewshot_percent=5,
    learning_rate=None,
)
# Out:
# INFO:p-16243:t-139859228541056:get_model.py:get_model:Loading model from: ibm-granite/granite-timeseries-ttm-r2
# INFO:p-16243:t-139859228541056:get_model.py:get_model:Selected prediction_length = 96
# WARNING:p-16243:t-139859228541056:get_model.py:get_model:Requested `prediction_length` (48) is not exactly equal to any of the available TTM prediction lengths.
#                     Hence, TTM will forecast using the `prediction_filter_length` argument to provide the requested prediction length.
#                     Supported context lengths (CL) and forecast/prediction lengths (FL) for Model Card: ibm-granite/granite-timeseries-ttm-r2 are
#                     {'CL': [512, 1024, 1536], 'FL': [96, 192, 336, 720]}
# -------------------- Running few-shot 5% --------------------
# INFO:p-16243:t-139859228541056:get_model.py:get_model:Model loaded successfully!
# INFO:p-16243:t-139859228541056:get_model.py:get_model:[TTM] context_len = 1536, forecast_len = 96
# INFO:p-16243:t-139859228541056:lr_finder.py:optimal_lr_finder:LR Finder: Running learning rate (LR) finder algorithm. If the suggested LR is very low, we suggest setting the LR manually.
# INFO:p-16243:t-139859228541056:lr_finder.py:optimal_lr_finder:LR Finder: Using GPU:0.
# Number of params before freezing backbone 3081120
# Number of params after freezing the backbone 1054560
# INFO:p-16243:t-139859228541056:lr_finder.py:optimal_lr_finder:LR Finder: Suggested learning rate = 0.00043287612810830566
# OPTIMAL SUGGESTED LEARNING RATE = 0.00043287612810830566
# Using learning rate = 0.00043287612810830566
#     <div>
#
#       <progress value='66' max='600' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 66/600 00:35 < 04:59, 1.78 it/s, Epoch 11/100]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.447300</td>
#       <td>0.208312</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.317300</td>
#       <td>0.208955</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.188700</td>
#       <td>0.209957</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.234500</td>
#       <td>0.211354</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.159400</td>
#       <td>0.212842</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.175400</td>
#       <td>0.213987</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.132100</td>
#       <td>0.214161</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.095600</td>
#       <td>0.212701</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.078500</td>
#       <td>0.210954</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.059500</td>
#       <td>0.213985</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.051300</td>
#       <td>0.216569</td>
#     </tr>
#   </tbody>
# </table><p>
# [TrackingCallback] Mean Epoch Time = 0.4894298856908625 seconds, Total Train Time = 36.232723236083984
# ++++++++++++++++++++ Test MSE after few-shot 5% fine-tuning ++++++++++++++++++++
#     <div>
#
#       <progress value='2' max='78' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 2/78 00:00 < 00:02, 32.85 it/s]
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 fewshot_finetune_eval(
#       2     dataset_name=TARGET_DATASET,
#       3     context_length=1536,
#       4     forecast_length=48,
#       5     batch_size=64,
#       6     fewshot_percent=5,
#       7     learning_rate=None,
#       8 )
#
# Cell In[24], line 134, in fewshot_finetune_eval(dataset_name, batch_size, learning_rate, context_length, forecast_length, fewshot_percent, freeze_backbone, num_epochs, save_dir, loss, quantile)
#     130 print("+" * 20, f"Test MSE after few-shot {fewshot_percent}% fine-tuning", "+" * 20)
#     132 finetune_forecast_trainer.model.loss = "mse"  # fixing metric to mse for evaluation
# --> 134 fewshot_output = finetune_forecast_trainer.evaluate(dset_test)
#     135 print(fewshot_output)
#     136 print("+" * 60)
#
# File ~/.local/lib/python3.12/site-packages/transformers/trainer.py:4073, in Trainer.evaluate(self, eval_dataset, ignore_keys, metric_key_prefix)
#    4070 start_time = time.time()
#    4072 eval_loop = self.prediction_loop if self.args.use_legacy_prediction_loop else self.evaluation_loop
# -> 4073 output = eval_loop(
#    4074     eval_dataloader,
#    4075     description="Evaluation",
#    4076     # No point gathering the predictions if there are no metrics, otherwise we defer to
#    4077     # self.args.prediction_loss_only
#    4078     prediction_loss_only=True if self.compute_metrics is None else None,
#    4079     ignore_keys=ignore_keys,
#    4080     metric_key_prefix=metric_key_prefix,
#    4081 )
#    4083 total_batch_size = self.args.eval_batch_size * self.args.world_size
#    4084 if f"{metric_key_prefix}_jit_compilation_time" in output.metrics:
#
# File ~/.local/lib/python3.12/site-packages/transformers/trainer.py:4267, in Trainer.evaluation_loop(self, dataloader, description, prediction_loss_only, ignore_keys, metric_key_prefix)
#    4264         batch_size = observed_batch_size
#    4266 # Prediction step
# -> 4267 losses, logits, labels = self.prediction_step(model, inputs, prediction_loss_only, ignore_keys=ignore_keys)
#    4268 main_input_name = getattr(self.model, "main_input_name", "input_ids")
#    4269 inputs_decode = (
#    4270     self._prepare_input(inputs[main_input_name]) if "inputs" in args.include_for_metrics else None
#    4271 )
#
# File ~/.local/lib/python3.12/site-packages/transformers/trainer.py:4483, in Trainer.prediction_step(self, model, inputs, prediction_loss_only, ignore_keys)
#    4481 if has_labels or loss_without_labels:
#    4482     with self.compute_loss_context_manager():
# -> 4483         loss, outputs = self.compute_loss(model, inputs, return_outputs=True)
#    4484     loss = loss.mean().detach()
#    4486     if isinstance(outputs, dict):
#
# File ~/.local/lib/python3.12/site-packages/transformers/trainer.py:3731, in Trainer.compute_loss(self, model, inputs, return_outputs, num_items_in_batch)
#    3729         loss_kwargs["num_items_in_batch"] = num_items_in_batch
#    3730     inputs = {**inputs, **loss_kwargs}
# -> 3731 outputs = model(**inputs)
#    3732 # Save past state if it exists
#    3733 # TODO: this needs to be fixed and made cleaner later.
#    3734 if self.args.past_index >= 0:
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.local/lib/python3.12/site-packages/tsfm_public/models/tinytimemixer/modeling_tinytimemixer.py:1822, in TinyTimeMixerForPrediction.forward(self, past_values, future_values, past_observed_mask, future_observed_mask, output_hidden_states, return_loss, return_dict, freq_token, static_categorical_values)
#    1819 return_dict = return_dict if return_dict is not None else self.use_return_dict
#    1821 # past_values: tensor [batch_size x context_length x num_input_channels]
# -> 1822 model_output = self.backbone(
#    1823     past_values,
#    1824     past_observed_mask=past_observed_mask,
#    1825     output_hidden_states=output_hidden_states,
#    1826     return_dict=return_dict,
#    1827     freq_token=freq_token,
#    1828 )  # model_output: [batch_size x nvars x num_patch x d_model]
#    1830 if isinstance(model_output, tuple):
#    1831     model_output = TinyTimeMixerModelOutput(*model_output)
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.local/lib/python3.12/site-packages/tsfm_public/models/tinytimemixer/modeling_tinytimemixer.py:1589, in TinyTimeMixerModel.forward(self, past_values, past_observed_mask, output_hidden_states, return_dict, freq_token)
#    1585 patched_x = self.patching(scaled_past_values)  # [batch_size x num_input_channels x num_patch x patch_length
#    1587 enc_input = patched_x
# -> 1589 encoder_output = self.encoder(
#    1590     enc_input,
#    1591     output_hidden_states=output_hidden_states,
#    1592     return_dict=return_dict,
#    1593     freq_token=freq_token,
#    1594 )
#    1596 if isinstance(encoder_output, tuple):
#    1597     encoder_output = TinyTimeMixerEncoderOutput(*encoder_output)
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.local/lib/python3.12/site-packages/tsfm_public/models/tinytimemixer/modeling_tinytimemixer.py:1490, in TinyTimeMixerEncoder.forward(self, past_values, output_hidden_states, return_dict, freq_token)
#    1487 if self.positional_encoder is not None:
#    1488     patches = self.positional_encoder(patches)
# -> 1490 last_hidden_state, hidden_states = self.mlp_mixer_encoder(patches, output_hidden_states=output_hidden_states)
#    1492 if not return_dict:
#    1493     return tuple(
#    1494         v
#    1495         for v in [
#    (...)
#    1498         ]
#    1499     )
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.local/lib/python3.12/site-packages/tsfm_public/models/tinytimemixer/modeling_tinytimemixer.py:932, in TinyTimeMixerBlock.forward(self, hidden_state, output_hidden_states)
#     930 for mod in self.mixers:
#     931     if self.adaptive_patching_levels > 0:
# --> 932         embedding, hidden_states = mod(embedding)
#     933         all_hidden_states.extend(hidden_states)
#     934     else:
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.local/lib/python3.12/site-packages/tsfm_public/models/tinytimemixer/modeling_tinytimemixer.py:872, in TinyTimeMixerAdaptivePatchingBlock.forward(self, hidden)
#     869 all_hidden_states.append(hidden)
#     871 for mod in self.mixer_layers:
# --> 872     hidden = mod(hidden)
#     873     all_hidden_states.append(hidden)
#     875 hidden = torch.reshape(
#     876     hidden,
#     877     (
#    (...)
#     882     ),
#     883 )
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.local/lib/python3.12/site-packages/tsfm_public/models/tinytimemixer/modeling_tinytimemixer.py:813, in TinyTimeMixerLayer.forward(self, hidden)
#     811 if self.num_patches > 1:
#     812     hidden = self.patch_mixer(hidden)
# --> 813 hidden = self.feature_mixer(hidden)  # hidden: (batch_size x num_patches x d_model)
#     814 return hidden
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.local/lib/python3.12/site-packages/tsfm_public/models/tinytimemixer/modeling_tinytimemixer.py:575, in FeatureMixerBlock.forward(self, hidden)
#     572 hidden = self.mlp(hidden)
#     574 if self.gated_attn:
# --> 575     hidden = self.gating_block(hidden)
#     577 out = hidden + residual
#     578 return out
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.local/lib/python3.12/site-packages/tsfm_public/models/tinytimemixer/modeling_tinytimemixer.py:86, in TinyTimeMixerGatedAttention.forward(self, inputs)
#      85 def forward(self, inputs):
# ---> 86     attn_weight = self.attn_softmax(self.attn_layer(inputs))
#      87     inputs = inputs * attn_weight
#      88     return inputs
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
